# %% [markdown]
# <a href="https://colab.research.google.com/github/dlscks/pythondemo/blob/main/python_24_matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 참고 사이트
# https://wikidocs.net/92071

# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd /content/drive/MyDrive/python_demo
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/python_demo

# %% [markdown]
# ### import

# %%
import numpy as np
import pandas as pd
import matplotlib as mp
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### State Machine
# - MATLAB -> State Machine 변수를 지정하지 않아도 가까이 변수를 가져와서 사용한다.
#
# - State Machine 예시
#  - a = 1
#     - 3변수를 지정하지 않아도 덧셈이 실행되어 a는 4가 된다.

# %%
from ctypes import sizeof
fig = plt.figure(figsize=(10, 5))
ax1 = fig.add_subplot(1,2,1) # 전체 창을 가로 1칸, 세로 2칸으로 나눈 후 첫 번째 칸에 ax1의 Axes을 생성
ax1.set(xlim=[0,8], ylim=[0,30], title='AX1 Example', xlabel='xAxis', ylabel='yAxis')
x = np.array([1,3,6,4])
y = np.array([1,10,5,20])
ax1.plot(x,y,'bo--', color='r',label='Price ($)')
ax1.legend(loc='upper left')

ax2 = fig.add_subplot(1,2,2) # 전체 창을 가로 1칸, 세로 2칸으로 나눈 후 두 번째 칸에 ax2의 Axes을 생성
ax2.set_xlim([0,10])
ax2.set_ylim([0,30])
ax2.set_title('AX2 Example', size=30)
ax2.set_xlabel('xAxis', size = 15)
ax2.set_ylabel('yAxis',size = 15)
ax2.scatter(x,y, marker='*', color='orange')
plt.show()

# %% [markdown]
# - plot은 데이터를 가지고 그래프를 그린다.
# - matplotlib은 기본적으로 figure, axes, plot을 기본 구조로 한다.

# %%
plt.figure()
plt.axes()
# plot()에 한개의 값만 지정하면 y축의 값으로 사용한다.
# x축은 지정을 하지 않으면 자동으로 1씩 증가가 된다.
plt.plot([1,2,3,4])
plt.plot([3,4,5,6])

# %% [markdown]
# figure, axes를 생략해도 알아서 실행해 준다.

# %%
plt.plot([1,2,3,4])

# %%
# 그래프에 제목을 설정한다.
plt.title('Title')
plt.plot([1,2,3,4])

# %% [markdown]
# ### 구글 코랩에서 한글 문제 해결
# - 아래 코드 설치를 한다.
# - 코랩 런타임 -> 런타임 다시 시작한다.

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf

# %%
plt.rc('font', family='NanumBarunGothic') 
plt.title('제목')
plt.plot([1,2,3,4])

# %%
# grid 는 격자무늬를 표시한다.
plt.title('한글')
plt.grid()
plt.xlabel('x축')
plt.ylabel('y축', rotation=0)

# x축 눈금
plt.xticks([1,2,3], rotation=-20)

plt.yticks(ticks=[2,3,4], labels=['A','B','C'])

plt.ylim(0,5)
plt.plot([1,2,3])

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
type(tips)
# Out:
# pandas.core.frame.DataFrame

# %%
tips.groupby('sex')

# %%
type(tips.groupby('sex')['tip'].mean())
# Out:
# pandas.core.series.Series

# %%
tips.groupby('sex')['tip'].mean().plot()

# %%
dir(tips.groupby('sex')['tip'].mean().plot)
# Out:
# ['__annotations__',
#  '__call__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_accessors',
#  '_all_kinds',
#  '_common_kinds',
#  '_constructor',
#  '_dataframe_kinds',
#  '_dir_additions',
#  '_dir_deletions',
#  '_get_call_args',
#  '_hidden_attrs',
#  '_kind_aliases',
#  '_parent',
#  '_reset_cache',
#  '_series_kinds',
#  'area',
#  'bar',
#  'barh',
#  'box',
#  'density',
#  'hexbin',
#  'hist',
#  'kde',
#  'line',
#  'pie',
#  'scatter']

# %%
plt.style.use('classic')
tips.groupby('sex')['tip'].mean().plot.bar(color='r')

# %%
# https://matplotlib.org/stable/api/legend_api.html
plt.style.use('ggplot')
tips.groupby('sex')['tip'].mean().plot.bar(color='gray')
plt.legend(fontsize=15,loc=8)
